# %% [markdown]
# <a href="https://colab.research.google.com/github/paulo10011/enyudi_proj/blob/main/DATA_SCIENCE/MiningPython_ALBERTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data Mining Using Python**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Shop.csv** and **Movies.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# Set-up
import csv

# %% [markdown]
# **Look at CSV files:** TID,item pairs

# %%
# Read shopping dataset from CSV file
# Create dictionary "Sitems" with key = item and value = set of transactions
# Also set variable Snumtrans = number of transactions
Sitems = {}
trans = []  # list of transactions used to set Snumtrans
with open('Shop.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Sitems:
            Sitems[r['item']] = {r['TID']}
        else:
            Sitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Snumtrans = len(trans)
print('Number of transactions:', Snumtrans)
print('Number of distinct items:', len(Sitems))
print('Item dictionary:')
Sitems
# Out:
# Number of transactions: 5
# Number of distinct items: 5
# Item dictionary:
# {'milk': {'1', '2', '4', '5'},
#  'eggs': {'1', '3', '4'},
#  'juice': {'1', '2', '5'},
#  'cookies': {'2', '5'},
#  'chips': {'3', '5'}}

# %%
# Read movies dataset from CSV file
# Create dictionary "Mitems" with key = item and value = set of transactions
# Also set variable Mnumtrans = number of transactions
Mitems = {}
trans = []  # list of transactions used to set Mnumtrans
with open('Movies.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Mitems:
            Mitems[r['item']] = {r['TID']}
        else:
            Mitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Mnumtrans = len(trans)
print('Number of transactions (users):', Mnumtrans)
print('Number of distinct items (movies):', len(Mitems))
print('Item dictionary:')
Mitems.items()
# Out:
# Number of transactions (users): 1382
# Number of distinct items (movies): 123
# Item dictionary:
# dict_items([('The Fault in Our Stars', {'215987', '114602', '71268', '102901', '34280', '29139', '218424', '237123', '229131', '105996', '206129', '140380', '214778', '244116', '174077', '69391', '204050', '221712', '18805', '163775', '126898', '6802', '89200', '71352', '134268', '153533', '176880', '127474', '69759', '39827', '61803', '243482', '46770', '176', '111288', '56323', '191042', '151368', '168240', '158048', '41453', '25851', '171673', '3508', '124830', '38153', '210968', '72265', '152735', '43142', '101420', '128828', '87907', '173452', '120662', '171575', '121408', '144712', '15590', '166205', '232001', '15530', '167831', '241916', '87127', '174147', '50601', '184040', '152646', '14642', '128203', '31198', '58296', '68551', '4208', '12924', '186450', '98509', '7353', '54858', '206146', '240694', '121896', '55096', '241263', '6573', '100316', '28304', '150676', '233542', '232320', '102371', '184307', '218669', '22793', '96530', '165260', '4231', '47173', '158208', '239816', '36040', '54212', '200931', '62076', '145755', '92094', '115516', '234322', '105787', '78715'}), ('Boyhood', {'215987', '39070', '122188', '64144', '71268', '72653', '34280', '167614', '29139', '182961', '52898', '139205', '179625', '3962', '27365', '147652', '87948', '206129', '98732', '139324', '228748', '106668', '44027', '244116', '78095', '177422', '75928', '124349', '170329', '87122', '133012', '105750', '99876', '126382', '228452', '3266', '7556', '148467', '40926', '89562', '110968', '94774', '221712', '115171', '34950', '207966', '196565', '116822', '201218', '26073', '163775', '14902', '66551', '18805', '162786', '9444', '71301', '6592', '126624', '153533', '156989', '94344', '127474', '15273', '39827', '243482', '94957', '68930', '180951', '9585', '208149', '220810', '96721', '13710', '176', '111288', '129638', '132287', '159840', '229857', '168240', '146607', '140741', '77949', '20316', '243657', '115786', '74343', '214091', '6569', '124830', '145136', '73352', '38153', '5415', '27210', '241577', '63672', '72265', '57305', '176934', '199241', '90516', '49159', '43142', '138121', '24214', '101420', '68079', '200039', '213657', '99742', '143932', '214028', '17264', '12354', '106700', '197358', '87907', '74793', '8215', '141192', '153764', '246994', '144712', '230758', '241656', '15590', '208473', '55980', '232001', '6199', '204770', '46106', '48950', '50601', '207834', '184040', '14588', '233266', '13399', '70585', '211373', '75555', '75198', '216620', '244769', '150148', '247354', '34520', '204070', '213606', '90271', '152679', '95669', '150186', '68551', '4208', '116345', '77903', '72725', '17915', '131820', '117731', '50188', '56344', '51681', '206146', '240694', '7353', '79910', '241263', '6573', '76891', '100316', '233042', '14883', '150676', '99848', '246553', '216969', '232165', '160895', '194682', '90727', '222218', '176725', '196576', '125182', '169154', '15466', '15823', '128655', '184307', '220049', '99004', '218669', '182194', '34018', '35936', '238755', '4231', '4588', '47173', '123552', '209357', '158208', '176875', '36040', '4987', '3967', '179447', '205045', '62076', '39014', '94555', '73132', '198726', '102294', '145755', '98054', '92094', '151584', '202380', '105787', '71124', '40611', '27332'}), ('Big Hero 6', {'220272', '114602', '117631', '178377', '32458', '42585', '56105', '80715', '229260', '44027', '244116', '78095', '24427', '73076', '105122', '3288', '1503', '160276', '3266', '7556', '138474', '40926', '130384', '716', '225664', '130414', '207966', '130072', '146114', '116822', '201218', '359', '170755', '92806', '30814', '55855', '37254', '111288', '20660', '145904', '70985', '169472', '171673', '68470', '14654', '54810', '124830', '38153', '27210', '180177', '72265', '114382', '162485', '220660', '172916', '169713', '104559', '218549', '233616', '78473', '75806', '15590', '14588', '60194', '124677', '192921', '66207', '23684', '222806', '97790', '116345', '36445', '136734', '84555', '10096', '195656', '1187 ...

# %% [markdown]
# ### Some new Python features

# %%
# Iterating through dictionaries
for i in Sitems:
    print(i)
    print(Sitems[i])
# Out:
# milk
# {'4', '2', '5', '1'}
# eggs
# {'3', '4', '1'}
# juice
# {'5', '2', '1'}
# cookies
# {'5', '2'}
# chips
# {'3', '5'}

# %%
# Intersecting sets
# How many transactions contain both eggs and milk?
set1 = Sitems['eggs']
print('Transactions containing eggs:', set1)
set2 = Sitems['milk']
print('Transactions containing milk:', set2)
set3 = set1 & set2
print('Transactions containing both:', set3)
# print('Number of transactions containing both:', len(set3))
# Out:
# Transactions containing eggs: {'3', '4', '1'}
# Transactions containing milk: {'4', '2', '5', '1'}
# Transactions containing both: {'4', '1'}

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### Print all pairs of items and the number of transactions they occur together in (see what's wrong and fix it)

# %%
for i1 in Sitems:
    for i2 in Sitems:
        common = len(Sitems[i1] & Sitems[i2])
        print([i1, i2, common])
# Out:
# ['milk', 'milk', 4]
# ['milk', 'eggs', 2]
# ['milk', 'juice', 3]
# ['milk', 'cookies', 2]
# ['milk', 'chips', 1]
# ['eggs', 'milk', 2]
# ['eggs', 'eggs', 3]
# ['eggs', 'juice', 1]
# ['eggs', 'cookies', 0]
# ['eggs', 'chips', 1]
# ['juice', 'milk', 3]
# ['juice', 'eggs', 1]
# ['juice', 'juice', 3]
# ['juice', 'cookies', 2]
# ['juice', 'chips', 1]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['cookies', 'cookies', 2]
# ['cookies', 'chips', 1]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]
# ['chips', 'chips', 2]

# %% [markdown]
# #### Now only print pairs that meet support threshold

# %%
support = .3
for i1 in Sitems:
    for i2 in Sitems:
      if i1 < i2:
        common = len(Sitems[i1] & Sitems[i2])
        if common/Snumtrans > support:
          print(i1, '|', i2)
# Out:
# eggs | milk
# juice | milk
# cookies | milk
# cookies | juice

# %% [markdown]
# ### Frequent item-sets of three

# %%
support = .1
for i1 in Sitems:
    for i2 in Sitems:
        for i3 in Sitems:
            if i1 < i2 and i2 < i3:
                common = len(Sitems[i1] & Sitems[i2] & Sitems[i3])
                if common/Snumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# eggs | juice | milk
# cookies | juice | milk
# chips | juice | milk
# chips | cookies | milk
# chips | cookies | juice

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
print(Mnumtrans, 'transactions (users)')
print(len(Mitems), 'distinct items (movies)')
# Out:
# 1382 transactions (users)
# 123 distinct items (movies)

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
# Frequent item-sets of three
support = 0.03
count_3 = 0
count_4 = 0

for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
          if i1 < i2 and i2 < i3:
            common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
            if common/Mnumtrans > support:
              count_3 += 1
              print(i1, '|', i2, '|', i3)
              if count_3 >= 10 and count_3 <= 20:
                print('Number of frequent item-sets of three:', count_3)
# Out:
# Boyhood | Inside Out | The Imitation Game
# Boyhood | Gone Girl | The Imitation Game
# Boyhood | Gone Girl | Inside Out
# Boyhood | Fury | The Imitation Game
# Boyhood | Fury | Gone Girl
# Big Hero 6 | Boyhood | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl
# Big Hero 6 | Inside Out | The Imitation Game
# Big Hero 6 | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out
# Number of frequent item-sets of three: 10
# Big Hero 6 | Fury | The Imitation Game
# Number of frequent item-sets of three: 11
# Big Hero 6 | Fury | Gone Girl
# Number of frequent item-sets of three: 12
# Gone Girl | Inside Out | The Imitation Game
# Number of frequent item-sets of three: 13
# Fury | Gone Girl | The Imitation Game
# Number of frequent item-sets of three: 14

# %%
# Frequent item-sets of four
support = 0.03

for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            for i4 in Mitems:
                if i1 < i2 and i2 < i3 and i3 < i4:
                    # Intersection of four sets of user IDs
                    common = len(Mitems[i1] & Mitems[i2] & Mitems[i3] & Mitems[i4])
                    if common / Mnumtrans > support:
                        count_4 += 1
                        print(f"{i1} | {i2} | {i3} | {i4}")

print('Number of frequent item-sets of four:', count_4)
# Out:
# Boyhood | Gone Girl | Inside Out | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out | The Imitation Game
# Number of frequent item-sets of four: 7

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence (see what's wrong and fix it)

# %%
# S -> i

confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        common = len(Sitems[lhs[0]] & Sitems[i])
        if common/lhs[1] > confidence:
            print(lhs[0], '->', i)
# Out:
# milk -> milk
# milk -> juice
# eggs -> milk
# eggs -> eggs
# juice -> milk
# juice -> juice
# juice -> cookies

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
# S = [JUICE, MILK]
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence

# %%
confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            if common/lhs[2] > confidence:
                print(lhs[0], '|', lhs[1], '->', i)
# Out:
# juice | milk -> cookies

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[i])
            lift = (common/lhs[1]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '->', i, ' lift:', lift)
# Out:
# milk -> juice  lift: 1.25
# milk -> cookies  lift: 1.25
# juice -> milk  lift: 1.25
# juice -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            lift = (common/lhs[2]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '->', i, ' lift:', lift)
# Out:
# juice | milk -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
# Association rules with three items on the left-hand side
# Hint: Make sure to include the code from the seprate cells above that
#   together implement the two steps of association rule mining
support = 0.05
confidence = 0.35
frequentLHS = []

for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common])

print(f"Number of frequent 3-itemsets: {len(frequentLHS)}")

rule_count = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            intersection_count = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            conf = intersection_count / lhs[3]

            if conf > confidence:
                print(f"{lhs[0]} | {lhs[1]} | {lhs[2]} -> {i} | confidence: {conf:.3f}")
                rule_count += 1

print(f"\nTotal association rules: {rule_count}")
# Out:
# Number of frequent 3-itemsets: 6
# Boyhood | Gone Girl | The Imitation Game -> Big Hero 6 | confidence: 0.484
# Boyhood | Gone Girl | The Imitation Game -> Inside Out | confidence: 0.442
# Boyhood | Gone Girl | The Imitation Game -> Fury | confidence: 0.411
# Big Hero 6 | Inside Out | The Imitation Game -> Gone Girl | confidence: 0.578
# Big Hero 6 | Gone Girl | The Imitation Game -> Boyhood | confidence: 0.387
# Big Hero 6 | Gone Girl | The Imitation Game -> Inside Out | confidence: 0.496
# Big Hero 6 | Gone Girl | Inside Out -> Boyhood | confidence: 0.400
# Big Hero 6 | Gone Girl | Inside Out -> The Imitation Game | confidence: 0.694
# Gone Girl | Inside Out | The Imitation Game -> Boyhood | confidence: 0.408
# Gone Girl | Inside Out | The Imitation Game -> Big Hero 6 | confidence: 0.573
# Fury | Gone Girl | The Imitation Game -> Boyhood | confidence: 0.557
# Fury | Gone Girl | The Imitation Game -> Big Hero 6 | confidence: 0.514
# Fury | Gone Girl | The Imitation Game -> Inside Out | confidence: 0.514
#
# Total association rules: 13

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20. Only consider lift thresholds > 1.

# %%
# Association rules with three items on the left-hand side
# Thresholds
support = 0.02
liftthresh = 2.3
frequentLHS = []

for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common_lhs = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common_lhs / Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common_lhs])

print(f"Number of frequent 3-itemsets found: {len(frequentLHS)}")

rule_count = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common_all = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])

            if common_all / Mnumtrans > support:
                confidence = common_all / lhs[3]
                rhs_support = len(Mitems[i]) / Mnumtrans
                lift = confidence / rhs_support

                if lift > liftthresh:
                    print(f"{lhs[0]} | {lhs[1]} | {lhs[2]} -> {i} | lift: {lift:.3f}")
                    rule_count += 1

print("-" * 30)
print(f"Total association rules: {rule_count}")
# Out:
# Number of frequent 3-itemsets found: 26
# Boyhood | Inside Out | The Imitation Game -> Big Hero 6 | lift: 2.404
# Boyhood | Gone Girl | The Imitation Game -> Fury | lift: 4.111
# Boyhood | Fury | The Imitation Game -> Big Hero 6 | lift: 2.325
# Big Hero 6 | Boyhood | The Imitation Game -> Fury | lift: 4.919
# Big Hero 6 | Inside Out | The Imitation Game -> Fury | lift: 2.749
# Big Hero 6 | Gone Girl | The Imitation Game -> Boyhood | lift: 2.343
# Big Hero 6 | Gone Girl | The Imitation Game -> Fury | lift: 3.030
# Big Hero 6 | Gone Girl | Inside Out -> Boyhood | lift: 2.425
# Big Hero 6 | Gone Girl | Inside Out -> Fury | lift: 3.417
# Big Hero 6 | Fury | The Imitation Game -> Boyhood | lift: 3.857
# Gone Girl | Inside Out | The Imitation Game -> Boyhood | lift: 2.472
# Gone Girl | Inside Out | The Imitation Game -> Fury | lift: 3.500
# Fury | Inside Out | The Imitation Game -> Big Hero 6 | lift: 2.564
# Fury | Gone Girl | The Imitation Game -> Boyhood | lift: 3.377
# Fury | Gone Girl | Inside Out -> Big Hero 6 | lift: 2.589
# ------------------------------
# Total association rules: 15
